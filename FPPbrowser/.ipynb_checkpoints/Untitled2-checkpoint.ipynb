# %%
from isochrones.dartmouth import Dartmouth_Isochrone
dar = Dartmouth_Isochrone()
import isochrones
model = isochrones.StarModel(dar, Teff=(5750, 100), logg=(4.5, 0.1), feh=(0.0, 0.1))
model.fit()
model.triangle()
# Out:
# WARNING:root:MultiNest not available; use_emcee being set to True

# %%
import vespa
# Out:
# WARNING:root:progressbar not imported

# %%
starpop = vespa.MultipleStarPopulation(1)

# %%
j = list(starpop.stars.keys())

# %%
j
# Out:
# ['H_mag',
#  'H_mag_A',
#  'J_mag',
#  'J_mag_A',
#  'K_mag',
#  'K_mag_A',
#  'Kepler_mag',
#  'Kepler_mag_A',
#  'Teff_A',
#  'age_A',
#  'g_mag',
#  'g_mag_A',
#  'i_mag',
#  'i_mag_A',
#  'logL_A',
#  'logg_A',
#  'mass_A',
#  'r_mag',
#  'r_mag_A',
#  'radius_A',
#  'z_mag',
#  'z_mag_A',
#  'H_mag_B',
#  'J_mag_B',
#  'K_mag_B',
#  'Kepler_mag_B',
#  'Teff_B',
#  'age_B',
#  'g_mag_B',
#  'i_mag_B',
#  'logL_B',
#  'logg_B',
#  'mass_B',
#  'r_mag_B',
#  'radius_B',
#  'z_mag_B',
#  'H_mag_C',
#  'J_mag_C',
#  'K_mag_C',
#  'Kepler_mag_C',
#  'Teff_C',
#  'age_C',
#  'g_mag_C',
#  'i_mag_C',
#  'logL_C',
#  'logg_C',
#  'mass_C',
#  'r_mag_C',
#  'radius_C',
#  'z_mag_C',
#  'distance',
#  'distmod']
